# %%
# !pip install transformers geopy folium torch --quiet

# %%
from transformers import pipeline
from geopy.geocoders import Nominatim
import folium

# Initialize NLP model
sentiment = pipeline("sentiment-analysis")
geolocator = Nominatim(user_agent="geoapi")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
city = "Paris"
location = geolocator.geocode(city)

#  Define sample attraction spots and mock reviews
spots = {
    "Eiffel Tower": "The view was breathtaking and unforgettable!",
    "Louvre Museum": "Too crowded, but the art was amazing.",
    "Notre Dame": "Beautiful cathedral, though a bit overrated.",
}

# %%
#  Map setup
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=12)

# Analyze and mark sentiment
for place, review in spots.items():
    result = sentiment(review)[0]
    emoji = "😊" if result['label'] == 'POSITIVE' else "☹️"
    popup_text = f"{place}: {result['label']} ({result['score']:.2f}) {emoji}"
    folium.Marker(location=[location.latitude + 0.01, location.longitude + 0.01],
                  popup=popup_text).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5909eb37f6f0f02bd9cb1bed74bb0407 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5909eb37f6f0f02bd9cb1bed74bb0407&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5909eb37f6f0f02bd9cb1bed74bb0407 = L.map(
#                 &quot;map_5909eb37f6f0f02bd9cb1bed74bb0407&quot;,
#                 {
#                     center: [48.8534951, 2.3483915],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29495eaa81ad3a9c3aebfe7038f0d43a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29495eaa81ad3a9c3aebfe7038f0d43a.addTo(map_5909eb37f6f0f02bd9cb1bed74bb0407);
#
#
#             var marker_9aa0d79aae02a5c2392aac8ef7bcb2f0 = L.marker(
#                 [48.8634951, 2.3583914999999998],
#                 {
# }
#             ).addTo(map_5909eb37f6f0f02bd9cb1bed74bb0407);
#
#
#         var popup_12e5d1e24b2f9b9ff1b4e0f48b2d4b57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ab5f91e271a9037b3eb60a115fbc9c8 = $(`&lt;div id=&quot;html_2ab5f91e271a9037b3eb60a115fbc9c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eiffel Tower: POSITIVE (1.00) 😊&lt;/div&gt;`)[0];
#                 popup_12e5d1e24b2f9b9ff1b4e0f48b2d4b57.setContent(html_2ab5f91e271a9037b3eb60a115fbc9c8);
#
#
#
#         marker_9aa0d79aae02a5c2392aac8ef7bcb2f0.bindPopup(popup_12e5d1e24b2f9b9ff1b4e0f48b2d4b57)
#         ;
#
#
#
#
#             var marker_f7cecbb468d254e9f43749aef337d2c4 = L.marker(
#                 [48.8634951, 2.3583914999999998],
#                 {
# }
#             ).addTo(map_5909eb37f6f0f02bd9cb1bed74bb0407);
#
#
#         var popup_38ec0b05f215df07aaacc63c0a523a11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d9eec5e39fd62754883660d79a70039 = $(`&lt;div id=&quot;html_9d9eec5e39fd62754883660d79a70039&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Louvre Museum: POSITIVE (1.00) 😊&lt;/div&gt;`)[0];
#                 popup_38ec0b05f215df07aaacc63c0a523a11.setContent(html_9d9eec5e39fd62754883660d79a70039);
#
#
#
#         marker_f7cecbb468d254e9f43749aef337d2c4.bindPopup(popup_38ec0b05f215df07aaacc63c0a523a11)
#         ;
#
#
#
#
#             var marker_0e9fa84925e51373e6dfcd6fbac50cb4 = L.marker(
#                 [48.8634951, 2.3583914999999998],
#                 {
# }
#             ).addTo(map_5909eb37f6f0f02bd9cb1bed74bb0407);
#
#
#         var popup_29ce235d1a938d9ca38c4e482ff5f008 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de9d22620ff3d0c924e44486d001dd36 = $(`&lt;div id=&quot;html_de9d22620ff3d0c924e44486d001dd36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Notre Dame: POSITIVE (1.00) 😊&lt;/div&gt;`)[0];
#                 popup_29ce235d1a938d9ca38c4e482ff5f008.setContent(html_de9d22620ff3d0c924e44486d001dd36);
#
#
#
#         marker_0e9fa84925e51373e6dfcd6fbac50cb4.bindPopup(popup_29ce235d1a938d9ca38c4e482ff5f008)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Step 1: Ask for city
city = input("Enter the city you want to explore: ")
location = geolocator.geocode(city)

# Step 2: Create a base map
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=12)

# Add instruction marker
folium.Marker(
    [location.latitude, location.longitude],
    popup="Click anywhere on map and note coordinates (Lat, Lon)",
    icon=folium.Icon(color="blue")
).add_to(m)

# Enable click for coordinate display
m.add_child(folium.LatLngPopup())

m
# Out:
# Enter the city you want to explore: Paris
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0abc7675347c8f867c253c9b12cf8aec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0abc7675347c8f867c253c9b12cf8aec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0abc7675347c8f867c253c9b12cf8aec = L.map(
#                 &quot;map_0abc7675347c8f867c253c9b12cf8aec&quot;,
#                 {
#                     center: [48.8534951, 2.3483915],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bbf3191f0a207294afeb2f72336cf88 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1bbf3191f0a207294afeb2f72336cf88.addTo(map_0abc7675347c8f867c253c9b12cf8aec);
#
#
#             var marker_35b58e3720f629f75541fccbe61cea18 = L.marker(
#                 [48.8534951, 2.3483915],
#                 {
# }
#             ).addTo(map_0abc7675347c8f867c253c9b12cf8aec);
#
#
#             var icon_ec2e955cb21094acea751a316af3ab17 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_15feb838f62506f49980e342a1c8d49e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_671fa50aecd7d73690548e7e2e8c087f = $(`&lt;div id=&quot;html_671fa50aecd7d73690548e7e2e8c087f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Click anywhere on map and note coordinates (Lat, Lon)&lt;/div&gt;`)[0];
#                 popup_15feb838f62506f49980e342a1c8d49e.setContent(html_671fa50aecd7d73690548e7e2e8c087f);
#
#
#
#         marker_35b58e3720f629f75541fccbe61cea18.bindPopup(popup_15feb838f62506f49980e342a1c8d49e)
#         ;
#
#
#
#
#                 marker_35b58e3720f629f75541fccbe61cea18.setIcon(icon_ec2e955cb21094acea751a316af3ab17);
#
#
#                 var lat_lng_popup_784d0692ed88e316aebe35c7d181c3d2 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_784d0692ed88e316aebe35c7d181c3d2
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_0abc7675347c8f867c253c9b12cf8aec);
#                     }
#                 map_0abc7675347c8f867c253c9b12cf8aec.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Enter clicked coordinates or place name
place_name = input("Enter the name or coordinates of the place you clicked: ")

# Try to geocode
try:
    loc = geolocator.geocode(place_name)
    if not loc:
        raise ValueError("Couldn't find that place.")
    review = input(f"Enter your comment or review for {place_name}: ")
    result = sentiment(review)[0]
    emoji = "😊" if result['label'] == 'POSITIVE' else "☹️"
    print(f"\n📍 {place_name}: {result['label']} ({result['score']:.2f}) {emoji}")

    # Display marker on map
    m2 = folium.Map(location=[loc.latitude, loc.longitude], zoom_start=14)
    folium.Marker(
        [loc.latitude, loc.longitude],
        popup=f"{place_name}: {result['label']} ({result['score']:.2f}) {emoji}",
        icon=folium.Icon(color="green" if result['label']=="POSITIVE" else "red")
    ).add_to(m2)
    m2

except Exception as e:
    print("Error:", e)
# Out:
# Enter the name or coordinates of the place you clicked: Paris
# Enter your comment or review for Paris: Amazing Place!
#
# 📍 Paris: POSITIVE (1.00) 😊

# %%
# 1️⃣ Sentiment model
sentiment = pipeline("sentiment-analysis")

# 2️⃣ Get coordinates of a city
geolocator = Nominatim(user_agent="geoapi")
city = "Paris"
location = geolocator.geocode(city)

# 3️⃣ Define sample attraction spots and mock reviews
spots = {
    "Eiffel Tower": "The view was breathtaking and unforgettable!",
    "Louvre Museum": "Too crowded, but the art was amazing.",
    "Notre Dame": "Beautiful cathedral, though a bit overrated.",
}

# 4️⃣ Map setup
m = folium.Map(location=[location.latitude, location.longitude], zoom_start=12)

# 5️⃣ Analyze and mark sentiment
for place, review in spots.items():
    result = sentiment(review)[0]
    emoji = "😊" if result['label'] == 'POSITIVE' else "☹️"
    popup_text = f"{place}: {result['label']} ({result['score']:.2f}) {emoji}"
    folium.Marker(location=[location.latitude + 0.01, location.longitude + 0.01],
                  popup=popup_text).add_to(m)

m
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2007f87bac21c07eaf94f47fa6d26bbf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2007f87bac21c07eaf94f47fa6d26bbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2007f87bac21c07eaf94f47fa6d26bbf = L.map(
#                 &quot;map_2007f87bac21c07eaf94f47fa6d26bbf&quot;,
#                 {
#                     center: [48.8534951, 2.3483915],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46a5b14067c642d32113f0a147ecae44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46a5b14067c642d32113f0a147ecae44.addTo(map_2007f87bac21c07eaf94f47fa6d26bbf);
#
#
#             var marker_1f8f6c4ded301e5beca4c7d380670bde = L.marker(
#                 [48.8634951, 2.3583914999999998],
#                 {
# }
#             ).addTo(map_2007f87bac21c07eaf94f47fa6d26bbf);
#
#
#         var popup_c1afc9ba4649374d5eb43b8aa2801a90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b15c1a1e396eaafaad22d5051ef98881 = $(`&lt;div id=&quot;html_b15c1a1e396eaafaad22d5051ef98881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eiffel Tower: POSITIVE (1.00) 😊&lt;/div&gt;`)[0];
#                 popup_c1afc9ba4649374d5eb43b8aa2801a90.setContent(html_b15c1a1e396eaafaad22d5051ef98881);
#
#
#
#         marker_1f8f6c4ded301e5beca4c7d380670bde.bindPopup(popup_c1afc9ba4649374d5eb43b8aa2801a90)
#         ;
#
#
#
#
#             var marker_f1666a734cffd3f59cdccabe1b015f72 = L.marker(
#                 [48.8634951, 2.3583914999999998],
#                 {
# }
#             ).addTo(map_2007f87bac21c07eaf94f47fa6d26bbf);
#
#
#         var popup_f7a7a6f606b3bb0d1996a060d16c7535 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7df1202fc537e6b98b111b55674e952 = $(`&lt;div id=&quot;html_f7df1202fc537e6b98b111b55674e952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Louvre Museum: POSITIVE (1.00) 😊&lt;/div&gt;`)[0];
#                 popup_f7a7a6f606b3bb0d1996a060d16c7535.setContent(html_f7df1202fc537e6b98b111b55674e952);
#
#
#
#         marker_f1666a734cffd3f59cdccabe1b015f72.bindPopup(popup_f7a7a6f606b3bb0d1996a060d16c7535)
#         ;
#
#
#
#
#             var marker_b2dd6d244c333abfb6f4465ef2554fb1 = L.marker(
#                 [48.8634951, 2.3583914999999998],
#                 {
# }
#             ).addTo(map_2007f87bac21c07eaf94f47fa6d26bbf);
#
#
#         var popup_7a1ab5cdfc64513683bc98dc4efada6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eec440483bab45ac9307e0de8e6a72a8 = $(`&lt;div id=&quot;html_eec440483bab45ac9307e0de8e6a72a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Notre Dame: POSITIVE (1.00) 😊&lt;/div&gt;`)[0];
#                 popup_7a1ab5cdfc64513683bc98dc4efada6a.setContent(html_eec440483bab45ac9307e0de8e6a72a8);
#
#
#
#         marker_b2dd6d244c333abfb6f4465ef2554fb1.bindPopup(popup_7a1ab5cdfc64513683bc98dc4efada6a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
